# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_data = pd.read_excel("D:\portfolio_2\HR_Data.xlsx")
my_data.head(5)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %% [markdown]
# REPORT GENDER IN COMPANY

# %%
#PREPARE DATA
count_gender = my_data.groupby('Gender').count()['Attrition'] # Tính số lượng giới tính theo Attrition
 
#PLOT BAR CHART
fig, ax = plt.subplots(figsize = (16,8))
ax.grid(which='major', color='#CCCCCC', linestyle='--')
ax.grid(which='minor', color='#CCCCCC', linestyle='--')
plt.bar(x = count_gender.index, height = count_gender.values, color = ['red','blue'])
plt.xlabel('Gender')
plt.ylabel('Number of people')
plt.title('Number of Gender distributions in Company');
label_of_gender = []
for i in range(len(count_gender.values)):
    cv_1 = str(count_gender.values[i])
    label_of_gender.append(cv_1)
for i in range(len(count_gender.values)): 
  plt.text(x = count_gender.index[i],  
  y = count_gender.values[i], 
  s = label_of_gender[i], 
  size = 15)

# %% [markdown]
# NO OF EMPLOYEE BY AGE GROUP

# %%
my_data.head(5)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
#PREPARE DATA
group_age = my_data.groupby('Age').count()['Attrition']

#PLOT BAR CHART
fig, ax = plt.subplots(figsize = (16,8))
        #1 plot plot chart on bar chart
ax = group_age.plot(x = group_age.index ,linestyle='-', marker='o',use_index = False , c = 'red')
group_age.plot( x = group_age.index, kind ='bar', ax = ax) 
plt.title('NO OF EMPLOYEE BY AGE GROUP ',size = 20)
plt.xlabel('Age',size = 15)
plt.xticks(rotation=0)
plt.ylabel('Number',size = 15);

# %% [markdown]
# Education field wise Attrition

# %%
my_data.head(3)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# 0  ...                  3                         1             80
# 1  ...                  4                         4             80
# 2  ...                  3                         2             80
#
#    Stock Option Level  Total Working Years  Work Life Balance  \
# ...

# %%
#PREPARE DATA
count_education = my_data.groupby('Education Field').count()['Attrition']
fig, ax = plt.subplots(figsize = (16,8))
colors = ['cyan','skyblue','lightpink','brown','black','#EE82EE']

#PLOT BARH CHART
plt.barh(y = count_education.index, width = count_education.values , color = colors, edgecolor='g')
plt.ylabel('Education',size = 15)
plt.xlabel('Number',size = 15)
plt.title('EDUCATATION FIELD WISE ATTRITION',size = 20);
label_of_num_education = []
for i in range(len(count_education.values)):
    cv_1 = str(count_education.values[i])
    label_of_num_education.append(cv_1)
for i in range(len(count_education.values)): 
  plt.text(x = count_education.values[i],  
  y = count_education.index[i], 
  s =  label_of_num_education[i], 
  size = 13)

# %% [markdown]
# DEPARTMENT WISE ATTRITION

# %%
my_data.head(5)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
# Prepare Data
department_groupby = my_data.groupby('Department').count()['Attrition']

# Plot pie Chart
plt.figure(figsize=(16, 8))
plt.pie(department_groupby.values,
        labels = department_groupby.index, 
        colors = ['#1E90FF', '#FA8072', '#ADFF2F'],
        autopct = '%1.1f%%',
        shadow = False,
        startangle=90)
plt.axis('equal')
plt.title("Average of Petal Length", fontsize=18);

# %%
my_data.head(5)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
#PREPARE DATA
groupby_ageband = my_data.groupby('CF_age band').count()['Attrition']


colors = ['red','blue','green','yellow','orange']
x_values = [x for x in range(len(groupby_ageband.values))]
count_age_label = []
for i in range(len(groupby_ageband.values)):
    z = str(groupby_ageband.values[i])
    count_age_label.append(z)

#PLOT BARCHART
fig, ax = plt.subplots(figsize = (16,8))
ax.grid(which='major', color='#CCCCCC', linestyle='--')
ax.grid(which='minor', color='#CCCCCC', linestyle='--')
plt.bar(x = groupby_ageband.index, height = groupby_ageband.values, color = colors)
plt.ylabel('Count',size = 15)
plt.xlabel('Age Group',size = 15)
plt.title('Age Band With Attrition',size = 20)
for i in range(len(count_age_label)): 
  plt.text(x = groupby_ageband.index[i],  
  y = groupby_ageband.values[i], 
  s = count_age_label[i], 
  size = 13)

# %% [markdown]
#     ATTRITION RATE BY GENDER FOR DIFFERENT AGE GROUP

# %%
gender_data = my_data[['Attrition','CF_age band','Gender']]
gender_data.head(5)
# Out:
#   Attrition CF_age band  Gender
# 0       Yes     35 - 44  Female
# 1        No     45 - 54    Male
# 2       Yes     35 - 44    Male
# 3        No     25 - 34  Female
# 4        No     25 - 34    Male

# %%
groupby_gender = gender_data.groupby(["CF_age band","Gender"], as_index = False)['Attrition'].count()
groupby_gender
# Out:
#   CF_age band  Gender  Attrition
# 0     25 - 34  Female        217
# 1     25 - 34    Male        337
# 2     35 - 44  Female        196
# 3     35 - 44    Male        309
# 4     45 - 54  Female        113
# 5     45 - 54    Male        132
# 6     Over 55  Female         25
# 7     Over 55    Male         44
# 8    Under 25  Female         37
# 9    Under 25    Male         60

# %%
def percentage(group_by):
    number = group_by.Attrition.astype(float)
    group_by['percent'] = round(number*100/number.sum(),2)
    return group_by
group_bygender = percentage(groupby_gender)
group_bygender
# Out:
#   CF_age band  Gender  Attrition  percent
# 0     25 - 34  Female        217    14.76
# 1     25 - 34    Male        337    22.93
# 2     35 - 44  Female        196    13.33
# 3     35 - 44    Male        309    21.02
# 4     45 - 54  Female        113     7.69
# 5     45 - 54    Male        132     8.98
# 6     Over 55  Female         25     1.70
# 7     Over 55    Male         44     2.99
# 8    Under 25  Female         37     2.52
# 9    Under 25    Male         60     4.08

# %%
data_under25 = group_bygender[(group_bygender['CF_age band'] == "Under 25")]
data_25_34 = group_bygender[(group_bygender['CF_age band'] == "25 - 34")]
data_35_44 = group_bygender[(group_bygender['CF_age band'] == "35 - 44")]
data_45_54 = group_bygender[(group_bygender['CF_age band'] == "45 - 54")]
data_Over55 = group_bygender[(group_bygender['CF_age band'] == "Over 55")]

# %%
def converttostring(x):
    con_vert = x.percent.astype(str)
    con_vert = con_vert + "%"
    return con_vert

# %%
fig, ax = plt.subplots(figsize = (12,4))

#UNDER25
x = data_under25
plt.title('ATTRITION RATE BY GENDER FOR DIFFERENT AGE UNDER 25')
plt.pie(x["percent"],
        labels = converttostring(x), 
        colors = ["red","blue"],
        autopct = '%1.2f%%',
        shadow = False,
        startangle=90)
plt.legend(x["Gender"],loc = "upper left")
plt.show()

#25-34
y = data_25_34
plt.title('ATTRITION RATE BY GENDER FOR DIFFERENT AGE 25-34')
plt.pie(y["percent"],
        labels = converttostring(y), 
        colors = ["red","blue"],
        autopct = '%1.2f%%',
        shadow = False,
        startangle=90)
plt.legend(y["Gender"],loc = "upper left")
plt.show()

#35 - 44
z = data_35_44
plt.title('ATTRITION RATE BY GENDER FOR DIFFERENT AGE 35-44')
plt.pie(z["percent"],
        labels = converttostring(z), 
        colors = ["red","blue"],
        autopct = '%1.2f%%',
        shadow = False,
        startangle=90)
plt.legend(z["Gender"],loc = "upper left")
plt.show()

#45 - 54
t = data_45_54
plt.title('ATTRITION RATE BY GENDER FOR DIFFERENT AGE 45-54')
plt.pie(t["percent"],
        labels = converttostring(t), 
        colors = ["red","blue"],
        autopct = '%1.2f%%',
        shadow = False,
        startangle=90)
plt.legend(t["Gender"],loc = "upper left")
plt.show()

#Over 55
r = data_Over55
plt.title('ATTRITION RATE BY GENDER FOR DIFFERENT AGE OVER 55')
plt.pie(r["percent"],
        labels = converttostring(r), 
        colors = ["red","blue"],
        autopct = '%1.2f%%',
        shadow = False,
        startangle=90)
plt.legend(r["Gender"],loc = "upper left")
plt.show()
